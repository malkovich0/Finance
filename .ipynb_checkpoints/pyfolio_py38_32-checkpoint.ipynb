# %%
import pyfolio as pf
# Out:
# C:\Anaconda3\envs\py38_32\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('Product/Momentum_5partial_11m_est_w_1m_gap_3m_selec_1m_rebal.csv',index_col=0)
# df.cumprod()

# %%
def date_to_date (date):
    date = date.split('-')
    date_new = datetime(int(date[0]),int(date[1]),int(date[2]))
    return date_new

# %%
df.index = [date_to_date(date) for date in df.index ]

# %%
df['1']
# Out:
# 2010-01-04    1.018220
# 2010-01-05    1.008316
# 2010-01-06    1.011251
# 2010-01-07    0.999927
# 2010-01-08    1.008024
#                 ...
# 2021-06-07    1.005431
# 2021-06-08    0.996215
# 2021-06-09    0.998876
# 2021-06-10    1.001630
# 2021-06-11    1.008159
# Name: 1, Length: 2824, dtype: float64

# %%
pf.create_returns_tear_sheet(df.Low-1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2010-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-06-11</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>134</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>5.591%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>83.975%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>20.86%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.37</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.10</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.56</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-54.31%</td>
#     </tr>
#     <tr>
# ...

# %%
pf.create_returns_tear_sheet(df['1']-1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2010-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-06-11</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>134</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>11.0%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>222.023%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>18.652%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.65</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.21</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-53.435%</td>
#     </tr>
#     <tr>
# ...

# %%
pf.create_returns_tear_sheet(df['2']-1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2010-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-06-11</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>134</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>12.942%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>291.112%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>18.51%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.75</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.24</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.88</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-53.295%</td>
#     </tr>
#     <tr>
# ...

# %%
pf.create_returns_tear_sheet(df['3']-1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2010-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-06-11</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>134</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>16.555%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>456.643%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>19.685%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.88</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.33</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-50.818%</td>
#     </tr>
#     <tr>
# ...

# %%
pf.create_returns_tear_sheet(df.High-1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2010-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-06-11</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>134</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>7.9%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>134.459%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>23.353%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.44</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.13</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.68</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-58.736%</td>
#     </tr>
#     <tr>
# ...

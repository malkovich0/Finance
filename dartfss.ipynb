# %%
import dart_fss as dart

# %%
# import dart_fss_classifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-31-c22bffc21ed7> in <module>
# ----> 1 import dart_fss_classifier
#
# ModuleNotFoundError: No module named 'dart_fss_classifier'

# %%
api_key = open('crtfc_key.txt',mode='r').readline()
dart.set_api_key(api_key=api_key)
# Out:
# 'f019243de247f120e3db654abec1d1ee6398eb72'

# %%
corp_list = dart.get_corp_list()
corp_list
# samsung = corp_list.find_by_corp_name('00126380', exactly=True)[0]

# %%
import FinanceDataReader as fdr
stock_list_kospi = fdr.StockListing('KOSPI')['Symbol'].to_list()
stock_list_kosdaq = fdr.StockListing('KOSDAQ')['Symbol'].to_list()
stock_df_del = fdr.StockListing('KRX-DELISTING')
stock_list_del = stock_df_del[(stock_df_del['Market'] == "KOSPI") | (stock_df_del['Market'] == "KOSDAQ")]['Symbol'].to_list()

# %%
import re
# stock_code_list 정제하기 (우선주, 리츠, 옵션) -> 6자리 숫자만, 맨 앞자리에 0 들어가는 것만
stock_code_list = []
for stock_code in stock_list_kospi:
    stock_code = re.findall("\d+", stock_code)[0] # 숫자만 추출한 뒤 첫번째 것만 사용
    if (stock_code[-1] == '0') and (len(stock_code) == 6):
        stock_code_list.append(stock_code)
len(stock_code_list)
# Out:
# 1298

# %%
# import requests
# import re
import pandas as pd
# import xlrd
# from urllib.request import urlopen
# from io import BytesIO
# from zipfile import ZipFile
import xml.etree.ElementTree as ET
# import time
# import FinanceDataReader as fdr
# from bs4 import BeautifulSoup
# import os
# import numpy as np

# %%
tree = ET.parse('Raw/Corpcode/corp_num/CORPCODE.xml')
root = tree.getroot()

corp_df = pd.DataFrame(columns=['corp_code','corp_name','stock_code','modify_date'])
for company in root.iter('list'):
    stock_code = company.findtext('stock_code')
    stock_code = stock_code.strip()
    if stock_code:
        company_dict = {
            'corp_code':company.findtext('corp_code'),
            'corp_name':company.findtext('corp_name'),
            'stock_code':company.findtext('stock_code'),
            'modify_date':company.findtext('modify_date')
        }
        corp_df = corp_df.append(company_dict, ignore_index=True)

# %%
def stock_code_reset(stock_code):
    corp_code = corp_df[corp_df['stock_code'] == stock_code].iloc[0, 0]
    return corp_code

# %%
stock_code = '001460'
stock_code_reset(stock_code)
# stock_code
# Out:
# '00122579'

# %%
stock_code_list
# Out:
# ['095570',
#  '006840',
#  '152100',
#  '295820',
#  '253150',
#  '253160',
#  '278420',
#  '292750',
#  '309170',
#  '309210',
#  '333940',
#  '333950',
#  '333960',
#  '333970',
#  '333980',
#  '269530',
#  '251590',
#  '161510',
#  '251600',
#  '289670',
#  '298340',
#  '189400',
#  '278620',
#  '269540',
#  '287180',
#  '213630',
#  '332610',
#  '332620',
#  '195970',
#  '238670',
#  '195980',
#  '373530',
#  '256450',
#  '239660',
#  '280920',
#  '266550',
#  '301400',
#  '301410',
#  '227830',
#  '122090',
#  '328370',
#  '301440',
#  '376250',
#  '027410',
#  '282330',
#  '138930',
#  '001460',
#  '021820',
#  '067830',
#  '033530',
#  '075580',
#  '027970',
#  '145210',
#  '308170',
#  '012600',
#  '068270',
#  '336370',
#  '248070',
#  '004430',
#  '017550',
#  '053210',
#  '134790',
#  '016590',
#  '029530',
#  '004970',
#  '011930',
#  '005390',
#  '004170',
#  '035510',
#  '034300',
#  '031430',
#  '031440',
#  '006880',
#  '005800',
#  '001720',
#  '009270',
#  '002700',
#  '019170',
#  '002870',
#  '500050',
#  '500040',
#  '500020',
#  '500030',
#  '500010',
#  '293940',
#  '055550',
#  '001770',
#  '004080',
#  '102280',
#  '003410',
#  '003620',
#  '004770',
#  '015540',
#  '004920',
#  '112610',
#  '008700',
#  '002790',
#  '090430',
#  '002030',
#  '183190',
#  '002310',
#  '012170',
#  '267850',
#  '020560',
#  '122900',
#  '010780',
#  '001780',
#  '018250',
#  '161000',
#  '011090',
#  '005850',
#  '012750',
#  '023960',
#  '298690',
#  '140910',
#  '078520',
#  '015260',
#  '007460',
#  '003060',
#  '244920',
#  '036570',
#  '138250',
#  '085310',
#  '009810',
#  '900140',
#  '014440',
#  '111770',
#  '009970',
#  '003520',
#  '000670',
#  '006740',
#  '012280',
#  '012160',
#  '015360',
#  '007310',
#  '002630',
#  '271560',
#  '001800',
#  '070960',
#  '316140',
#  '033660',
#  '118000',
#  '010050',
#  '006980',
#  '017370',
#  '105840',
#  '010400',
#  '049800',
#  '016880',
#  '095720',
#  '005820',
#  '010600',
#  '008600',
#  '033270',
#  '014830',
#  '000910',
#  '047400',
#  '011330',
#  '077500',
#  ...]

# %%
none_list=[]
error_list=[]
for stock_code in stock_code_list:
    data = corp_list.find_by_stock_code(stock_code)
    if data == None:
        none_list.append(stock_code)
        continue
    try:
        fs = dart.fs.extract(corp_code = stock_code_reset(stock_code), bgn_de='19990101',end_de='20210415',report_tp='quarter')
    except:
        error_list.append(stock_code)
        #         fs = data.extract_fs(bgn_de='19990101',end_de='20210415',separate = True, report_tp='quarter')
    fs.save(filename = '{}.xlsx'.format(stock_code), path="Raw/fssdata")
# Out:
# Annual reports:   0%|          | 0/14 [00:00<?, ?report/s]
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20130327000019', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2012.12)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20130327', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20120323000896', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '[기재정정]사업보고서 (2011.12)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20120323', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20110331001816', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2010.12)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20110331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20100331001530', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2009.12)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20100331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20090331002862', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2008.12)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20090331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20080331002812', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2007.12)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20080331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Semiannual reports:   0%|          | 0/14 [00:00<?, ?report/s]
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20140814001450', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '반기보고서 (2014.06)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20140814', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20130813000348', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '반기보고서 (2013.06)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20130813', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20120814000476', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '반기보고서 (2012.06)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20120814', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20110812000329', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '반기보고서 (2011.06)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20110812', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20100813000684', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '반기보고서 (2010.06)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20100813', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20090814002100', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '반기보고서 (2009.06)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20090814', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20080814002049', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '반기보고서 (2008.06)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20080814', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20070823000069', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '반기보고서 (2007.06)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20070823', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Quarterly reports:   0%|          | 0/28 [00:00<?, ?report/s]
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20140515000263', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2014.03)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20140515', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20131114000166', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2013.09)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20131114', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20130513000205', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2013.03)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20130513', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20121113000268', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2012.09)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20121113', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20120511000895', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2012.03)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20120511', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20111114001140', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2011.09)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20111114', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20110513004227', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2011.03)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20110513', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20101115000309', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2010.09)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20101115', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20100514002487', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2010.03)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20100514', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20091113001054', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2009.09)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20091113', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20090515002317', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2009.03)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20090515', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20081124000086', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '[기재정정]분기보고서 (2008.09)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20081124', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20080528000016', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '[기재정정]분기보고서 (2008.03)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20080528', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20071114001440', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2007.09)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20071114', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20070515001548', 'corp_code': '00365387', 'corp_name': 'AJ네트웍스', 'stock_code': '095570', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2007.03)', 'flr_nm': 'AJ네트웍스', 'rcept_dt': '20070515', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Annual reports:   0%|          | 0/22 [00:00<?, ?report/s]

# %%
# stock_code = '001040'
# data = corp_list.find_by_stock_code(stock_code)
fs_data = dart.fs.extract(corp_code ='00122579', bgn_de='19990101',end_de='20110101', report_tp='quarter')
# Out:
# Annual reports:   0%|          | 0/12 [00:00<?, ?report/s]
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:206: RuntimeWarning: Date data length does not match table header.So last date was set using last data(19000101).
#   warnings.warn(warnings_text, RuntimeWarning)
# Semiannual reports:   0%|          | 0/12 [00:00<?, ?report/s]
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20100816000439', 'corp_code': '00122579', 'corp_name': 'BYC', 'stock_code': '001460', 'corp_cls': 'Y', 'report_nm': '반기보고서 (2010.06)', 'flr_nm': 'BYC', 'rcept_dt': '20100816', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20090814001184', 'corp_code': '00122579', 'corp_name': 'BYC', 'stock_code': '001460', 'corp_cls': 'Y', 'report_nm': '반기보고서 (2009.06)', 'flr_nm': 'BYC', 'rcept_dt': '20090814', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:206: RuntimeWarning: Date data length does not match table header.So last date was set using last data(19000101).
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '19990813000228', 'corp_code': '00122579', 'corp_name': 'BYC', 'stock_code': '001460', 'corp_cls': 'Y', 'report_nm': '반기보고서 (1999.06)', 'flr_nm': 'BYC', 'rcept_dt': '19990813', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Quarterly reports:   0%|          | 0/22 [00:00<?, ?report/s]
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20101115000698', 'corp_code': '00122579', 'corp_name': 'BYC', 'stock_code': '001460', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2010.09)', 'flr_nm': 'BYC', 'rcept_dt': '20101115', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20100514002842', 'corp_code': '00122579', 'corp_name': 'BYC', 'stock_code': '001460', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2010.03)', 'flr_nm': 'BYC', 'rcept_dt': '20100514', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20091116000785', 'corp_code': '00122579', 'corp_name': 'BYC', 'stock_code': '001460', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2009.09)', 'flr_nm': 'BYC', 'rcept_dt': '20091116', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:1278: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20090515001573', 'corp_code': '00122579', 'corp_name': 'BYC', 'stock_code': '001460', 'corp_cls': 'Y', 'report_nm': '분기보고서 (2009.03)', 'flr_nm': 'BYC', 'rcept_dt': '20090515', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# C:\Users\malko\anaconda3\envs\py38_64\lib\site-packages\dart_fss\fs\extract.py:206: RuntimeWarning: Date data length does not match table header.So last date was set using last data(19000101).
#   warnings.warn(warnings_text, RuntimeWarning)

# %%
fs_data['bs']
# Out:
#     Statement of financial position(Unit: KWR)             20091231  \
#                                       label_ko            (연결재무제표,)
# 0                                           자산
# 1                                       Ⅰ.유동자산  4,166,164,665,000.0
# 2                                      (1)당좌자산  3,354,987,625,000.0
# 3                                   1.현금및현금성자산  1,226,315,235,000.0
# 4                                2.단기금융상품(주석3)    756,693,860,000.0
# ..                                         ...                  ...
# 127                                    2.임의적립금    411,970,710,000.0
# 128                                 3.미처분이익잉여금    156,484,999,000.0
# 129                                   Ⅵ.소수주주지분  1,860,617,241,000.0
# 130                                       자본총계  3,904,214,795,000.0
# 131                                    부채와자본총계 10,689,037,818,000.0
#
#                20081231
#               (연결재무제표,)
# 0
# 1   3,457,713,248,000.0
# 2   2,445,351,095,000.0
# 3     627,342,364,000.0
# 4     534,805,048,000.0
# ..                  ...
# 127   161,801,200,000.0
# 128   268,959,820,000.0
# 129 1,326,910,080,000.0
# 130 3,272,618,964,000.0
# 131 9,754,902,137,000.0
#
# [132 rows x 3 columns]

# %%
# html에 연결이 없는 경우에 전체로 별도만 가져온다. (2014년부터 연결?)
# xbrl이 없는 경우에는 마찬가지로 항목명을 맞춰야 한다.

# data = corp_list.find_by_stock_code(stock_code)
data == None
# Out:
# False

# %%
data = corp_list.find_by_stock_code('036670')
data
# Out:
# [00265041]KCI

# %%
try:
    fs = data.extract_fs(bgn_de='20190701',end_de='20200101',report_tp='quarter')
except:
    fs = data.extract_fs(bgn_de='20190101',end_de='20200101',separate = True, report_tp='quarter')
# Out:
# Annual reports:   0%|          | 0/1 [00:00<?, ?report/s]
# Semiannual reports:   0%|          | 0/1 [00:00<?, ?report/s]
# Quarterly reports:   0%|          | 0/2 [00:00<?, ?report/s]

# %%
stock_code
# Out:
# '003280'

# %%
fs.save(filename = '{}.xlsx'.format(stock_code), path="Raw/fssdata")
# Out:
# 'Raw/fssdata\\003280.xlsx'

# %%
fs = samsung.extract_fs(bgn_de='20120101')
# Out:
# Annual reports:   0%|          | 0/10 [00:00<?, ?report/s]

# %%
fs.save(path="Raw/fssdata")
# Out:
# 'Raw/fssdata\\00126380_annual.xlsx'

# %%
# Open DART API KEY 설정



# DART 에 공시된 회사 리스트 불러오기
# corp_list = dart.get_corp_list()

# 삼성전자 검색


# 2012년부터 연간 연결재무제표 불러오기
fs = samsung.extract_fs(bgn_de='20120101')

# 재무제표 검색 결과를 엑셀파일로 저장 ( 기본저장위치: 실행폴더/fsdata )
fs.save()
